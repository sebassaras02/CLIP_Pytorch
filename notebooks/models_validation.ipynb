# %%
import numpy as np
import pandas as pd
from torch import manual_seed

from transformers import DistilBertModel, ViTModel, AutoModelForMaskedLM

import sys

sys.path.append('../src')

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from dataset import CLIPChemistryDataset

# %% [markdown]
# Define random seeds

# %%
SEED = 99
np.random.seed(SEED)
manual_seed(SEED)

# %% [markdown]
# Define the Pytorch dataset

# %%
dataset = CLIPChemistryDataset(limit=10000)

# %% [markdown]
# Define the models

# %%
from model import CLIPChemistryModel, TextEncoderHead, ImageEncoderHead

# %%
from transformers import DistilBertModel, ViTModel, AutoModelForMaskedLM, ResNetModel

# %%
ENCODER_BASE = DistilBertModel.from_pretrained("distilbert-base-uncased")
IMAGE_BASE = ResNetModel.from_pretrained("microsoft/resnet-18")
text_encoder = TextEncoderHead(model=ENCODER_BASE)
image_encoder = ImageEncoderHead()

# %%
# import io
# from PIL import Image

# image_bytes = data.loc[0, 'image']['bytes']

# image = Image.open(io.BytesIO(image_bytes)).convert('L')

# %% [markdown]
# Testing the text encoder

# %%
image, input_ids, attention_mask = dataset[0]

# %%
# text_encoder(input_ids.unsqueeze(0), attention_mask.unsqueeze(0))

# %% [markdown]
# Testing the image encoder

# %%
import torch
test_image = torch.randn(3, 1, 64, 64)

# %%
image_encoder(test_image).shape
# Out:
# torch.Size([3, 512])

# %% [markdown]
# Testing the CLIP model

# %%
clip_model = CLIPChemistryModel(text_encoder=text_encoder, image_encoder=image_encoder)

# %%
image.unsqueeze(0).shape
# Out:
# torch.Size([1, 1, 64, 64])

# %%
image_encoder(image.unsqueeze(0)).shape
# Out:
# torch.Size([1, 512])

# %%
output3 = clip_model(image=image.unsqueeze(0), input_ids=input_ids.unsqueeze(0), attention_mask=attention_mask.unsqueeze(0))
